# %%
from IPython.display import HTML

HTML("""
<style>

    /* 1. Tamaño y espacio de los ítems de lista (li) */
    .reveal ul li, .reveal ol li {
        font-size: 32px !important;    /* Ajusta este valor */
        margin-bottom: 15px !important; /* Espacio entre puntos */
        line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
    }

    /* 2. Estilo de las sub-listas (listas dentro de listas) */
    .reveal li > ul li, .reveal li > ol li {
        font-size: 0.85em !important;   /* Un poco más pequeñas que las principales */
        list-style-type: circle !important; 
    }

    /* 3. Cambiar el color de las viñetas (bullets) */
    .reveal ul li::marker {
        color: #3498db !important;      /* Un azul sutil, cámbialo a tu gusto */
        font-weight: bold;
    }

    /* 4. Ajustar el ancho del contenedor para que las listas no se corten */
    .reveal .slides {
        text-align: left !important;    /* Alinea el texto a la izquierda si prefieres */
    }
    /* 5. Tamaño y espacio de los párrafos  (p) */
    .reveal p {
        font-size: 30px !important;    /* Ajusta este valor */
        margin-bottom: 15px !important; /* Espacio entre puntos */
        line-height: 1.3 !important;    /* Espacio entre líneas del mismo punto */
    }
     /* 6. Tamaño y espacio de la celda de codigos view */
   .reveal div pre {
        font-size: 20px !important;
    }
      /* 7. Tamaño y espacio de la celda de codigos  ESTO ES EL CÓDIGO QUE SE MUESTRA EN UNA CELDA MD
   .reveal div pre span {
        font-size: 32px !important;
    }*/
    /* Celdas de código edit*/
    .reveal .cm-line {
    font-size: 24px !important;
    }
       /* 8. esTILO H1, H2 y H3*/
   .reveal div h1{
        font-size: 48px !important;
        color: #4db6ac !important;
        text-transform: None;
    }
   .reveal div h2{
        font-size: 42px !important;
        text-transform: None;

    }
    .reveal div h3{
        /*font-size: 32px !important;*/
        text-transform: None !important;

    }
    
</style>
""")

# %% [markdown]
# # Lenguaje Python
#
# ## Cursada 2026
# ![](imagenes/marca-50-Anos-del-Golpe.png)
# ### Introducción al análisis de datos
# * pandas
# * Matplotlib

# %% [markdown]
# # Ciencia de datos:
#
# > En pocas palabras: se refiere al análisis significativo de datos aplicando  técnicas de programación sobre un área de conocimiento específico.
#
# <div>
#     <img src="imagenes/esquemadiapo2.png" width="500"/>
# </div>

# %% [markdown]
# ## ¿Cómo podemos representar datos?

# %% [markdown]
# * [Mapa](https://www.enre.gov.ar/mapacortes/index.html) de cortes de electricidad.
# * [Mapa](https://mapa.poblaciones.org/map) poblacional con información de los censos en Argentina.
# * [Mapa provincial](https://observatorio.laizquierdadiario.com/) sobre resultados de elecciones.

# %% [markdown]
# ## Manejo de archivo de datos
# * ¿Cuáles son las ventajas de utilizar pandas sobre las estructuras de datos estándar de Python?

# %% [markdown]
# * ¿Cómo puede simplificar las operaciones realizadas con los módulos **csv** y **json**?

# %% [markdown]
# * ¿Qué otros formatos de archivos conocen para almacenar datos?
# * ¿Cuáles son formatos abiertos?

# %% [markdown]
# ## Introducción a pandas
# *    ¿Qué es pandas y cuál es su importancia en el análisis de datos?
# *    ¿Cuáles son las principales estructuras de datos en pandas?
# *    ¿Cómo importar y explorar un conjunto de datos usando pandas?
# *    ¿Qué funcionalidades ofrece pandas para conocer, filtrar y modificar los datos?

# %% [markdown]
# ## 🎒 [**pandas**](https://pandas.pydata.org/)
# * Es una biblioteca de Python que proporciona estructuras de datos y herramientas de análisis de datos de alto rendimiento y fáciles de usar.
# * Esta orientada al análisis de datos porque permite manipular y analizar conjuntos de datos de manera eficiente.

# %%
import pandas as....

# %%
import pandas as pd

# %% [markdown]
# ### 📌 Tipo de archivos y estructuras de datos en pandas

# %% [markdown]
# ¿Qué tipo de datos usaron con para recorrer el contenido usando:
# * csv
# * json

# %% [markdown]
# #### Veamos un ejemplo

# %%
from pathlib import  Path
file_route = Path('ejemplos')/'clase10'
file_data = 'ar-airports.csv'
df_airports = pd.read_csv(file_route/file_data)

# %%
df_airports
# Out:
#          id    ident            type  \
# 0      5781     SAEZ   large_airport
# 1      5771     SABE   large_airport
# 2      5835     SAWH  medium_airport
# 3      5806     SARI  medium_airport
# 4      5831     SAWC  medium_airport
# ..      ...      ...             ...
# 951  333824  AR-0654          closed
# 952   42893  AR-0471        heliport
# 953  333815  AR-0652          closed
# 954   42903  AR-0481        heliport
# 955   42905  AR-0483        heliport
#
#                                                   name  latitude_deg  \
# 0             Minister Pistarini International Airport    -34.822200
# 1                                Jorge Newbery Airpark    -34.559200
# 2    Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3           Cataratas Del Iguazú International Airport    -25.737301
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# ..                                                 ...           ...
# 951                         Agrodistribuidora Airstrip    -29.220089
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 953                                Villa Unión Airport    -29.422180
# 954                                      Roca Heliport    -32.060000
# 955                              Austral S.A. Heliport    -52.738600
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -58.535800          67.0        SA    Argentina          AR  ...
# 1       -58.415600          18.0        SA    Argentina          AR  ...
# 2       -68.295800         102.0        SA    Argentina          AR  ...
# 3       -54.473400         916.0        SA    Argentina          AR  ...
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 951     -61.760298         220.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 953     -62.789526         248.0        SA    Argentina          AR  ...
# 954     -64.779400        3444.0        SA    Argentina          AR  ...
# 955     -68.572500         290.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 0                   1     SAEZ      SAEZ       EZE         EZE
# 1                   1     SABE      SABE       AEP         AER
# 2                   1     SAWH      SAWH       USH         USU
# 3                   1     SARI      SARI       IGR         IGU
# 4                   1     SAWC       NaN       FTE         ECA
# ..                ...      ...       ...       ...         ...
# 951                 0      NaN       NaN       NaN         NaN
# 952                 0      NaN       NaN       NaN         HNE
# 953                 0      NaN       NaN       NaN         NaN
# 954                 0      NaN       NaN       NaN         HYC
# 955                 0      NaN       NaN       NaN         HCP
#
#                                    home_link  \
# 0         http://www.aa2000.com.ar/index.php
# 1                                        NaN
# 2                                        NaN
# 3            http://www.aa2000.com.ar/iguazu
# 4    http://www.aeropuertoelcalafate.com/en/
# ..                                       ...
# 951                                      NaN
# 952                                      NaN
# 953                                      NaN
# 954                                      NaN
# 955                                      NaN
#
#                                         wikipedia_link     keywords score  \
# 0    https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1    https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2    https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
# 3    https://en.wikipedia.org/wiki/Cataratas_del_Ig...       Iguaçu   750
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...          NaN   500
# ..                                                 ...          ...   ...
# 951                                                NaN          NaN     0
# 952                                                NaN          NaN     0
# 953                                                NaN          NaN     0
# 954                                                NaN          NaN     0
# 955                                                NaN          NaN     0
#
#                   last_updated
# 0    2022-10-27T15:05:29+00:00
# 1    2021-10-07T15:55:36+00:00
# 2    2025-03-22T20:48:42+00:00
# 3    2018-09-13T12:34:47+00:00
# 4    2022-01-12T18:23:15+00:00
# ..                         ...
# 951  2020-04-12T12:30:36+00:00
# 952  2009-10-20T11:13:21+00:00
# 953  2020-04-10T04:01:54+00:00
# 954  2009-10-20T11:13:21+00:00
# 955  2021-10-07T11:46:03+00:00
#
# [956 rows x 24 columns]

# %% [markdown]
# ¿De qué tipo de datos es la variable utilizada?

# %%
type(df_airports)
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Las principales [estructuras de datos](https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html) en pandas
# * **Series**: es un arreglo unidimensional de datos etiquetados.
# * **DataFrame**: es una estructura de datos tabular bidimensional compuesta por filas y columnas.

# %% [markdown]
# <div style="display: flex;">
#     <div style="flex: 50%; padding: 5px;">
#         <img src="imagenes/dataframe.png" style="width: 70%;">
#     </div>
#     <div style="flex: 50%; padding: 5px;">
#         <img src="imagenes/series.png" style="width: 70%;">
#     </div>
# </div>

# %% [markdown]
# ### Tipo de archivos y formas de abrir:
# * **pd.read_csv()**:  para leer archivos CSV (Comma Separated Values).
# * **pd.read_excel()**:  para leer archivos de Excel.
# * **pd.read_json()**:  para leer archivos JSON.
# * **pd.read_html()**:  para leer tablas HTML de una página web.
# * **pd.read_sql()**:  para leer datos de una base de datos SQL.
# * **pd.read_hdf()**:  para leer archivos HDF5 (Hierarchical Data Format versión 5).
# * [Muchos más](https://pandas.pydata.org/docs/user_guide/io.html)
# * Más info sobre opciones para lectura de distintos tipos de  archivos:
# > Capítulo 6 "Python for Data Analysis"

# %% [markdown]
# ### 📌 Conociendo nuestros datos

# %% [markdown]
# Ver las primeras filas o últimas
# ```python
# df.head(number)
# df.tail(number)
# ```

# %%
df_airports.head(5)
# Out:
#      id ident            type  \
# 0  5781  SAEZ   large_airport
# 1  5771  SABE   large_airport
# 2  5835  SAWH  medium_airport
# 3  5806  SARI  medium_airport
# 4  5831  SAWC  medium_airport
#
#                                                 name  latitude_deg  \
# 0           Minister Pistarini International Airport    -34.822200
# 1                              Jorge Newbery Airpark    -34.559200
# 2  Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3         Cataratas Del Iguazú International Airport    -25.737301
# 4  El Calafate - Commander Armando Tola Internati...    -50.280300
#
#    longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0     -58.535800          67.0        SA    Argentina          AR  ...
# 1     -58.415600          18.0        SA    Argentina          AR  ...
# 2     -68.295800         102.0        SA    Argentina          AR  ...
# 3     -54.473400         916.0        SA    Argentina          AR  ...
# 4     -72.053101         669.0        SA    Argentina          AR  ...
#
#   scheduled_service gps_code icao_code iata_code  local_code  \
# 0                 1     SAEZ      SAEZ       EZE         EZE
# 1                 1     SABE      SABE       AEP         AER
# 2                 1     SAWH      SAWH       USH         USU
# 3                 1     SARI      SARI       IGR         IGU
# 4                 1     SAWC       NaN       FTE         ECA
#
#                                  home_link  \
# 0       http://www.aa2000.com.ar/index.php
# 1                                      NaN
# 2                                      NaN
# 3          http://www.aa2000.com.ar/iguazu
# 4  http://www.aeropuertoelcalafate.com/en/
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1  https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2  https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
# 3  https://en.wikipedia.org/wiki/Cataratas_del_Ig...       Iguaçu   750
# 4  https://en.wikipedia.org/wiki/Comandante_Arman...          NaN   500
#
#                 last_updated
# 0  2022-10-27T15:05:29+00:00
# 1  2021-10-07T15:55:36+00:00
# 2  2025-03-22T20:48:42+00:00
# 3  2018-09-13T12:34:47+00:00
# 4  2022-01-12T18:23:15+00:00
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Filas y columnas

# %%
df_airports.shape
# Out:
# (956, 24)

# %% [markdown]
# #### Nombres de las columnas
# Si trabajamos con un archivo csv, ¿en dónde se encuentran los nombres de las columnas?

# %%
df_airports.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'country_name', 'iso_country',
#        'region_name', 'iso_region', 'local_region', 'municipality',
#        'scheduled_service', 'gps_code', 'icao_code', 'iata_code', 'local_code',
#        'home_link', 'wikipedia_link', 'keywords', 'score', 'last_updated'],
#       dtype='str')

# %% [markdown]
# #### Información de nuestros datos
# * ¿Qué otra información nos puede servir, por ejemplo si vamos a buscar datos en la columna **municipality** del archivo de aeropuertos?
# * ¿Qué problemas tiene esta columna?

# %%
df_airports.municipality
# Out:
# 0        Buenos Aires (Ezeiza)
# 1                 Buenos Aires
# 2                      Ushuaia
# 3                Puerto Iguazu
# 4                  El Calafate
#                 ...
# 951                    Tostado
# 952                Villa Nueva
# 953                Villa Unión
# 954     Yacanto de Calamuchita
# 955    Yacimiento Cañadón Alfa
# Name: municipality, Length: 956, dtype: str

# %% [markdown]
# En principio no se se detecta un problema, pero utilicemos algunas funcionalidades para conocer los datos, antes de poder hacer un análisis de datos

# %%
df_airports.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 956 non-null    int64
#  1   ident              956 non-null    str
#  2   type               956 non-null    str
#  3   name               956 non-null    str
#  4   latitude_deg       956 non-null    float64
#  5   longitude_deg      956 non-null    float64
#  6   elevation_ft       923 non-null    float64
#  7   continent          956 non-null    str
#  8   country_name       956 non-null    str
#  9   iso_country        956 non-null    str
#  10  region_name        956 non-null    str
#  11  iso_region         956 non-null    str
#  12  local_region       956 non-null    str
#  13  municipality       941 non-null    str
#  14  scheduled_service  956 non-null    int64
#  15  gps_code           228 non-null    str
#  16  icao_code          93 non-null     str
#  17  iata_code          103 non-null    str
#  18  local_code         771 non-null    str
#  19  home_link          14 non-null     str
#  20  wikipedia_link     186 non-null    str
#  21  keywords           119 non-null    str
#  22  score              956 non-null    int64
#  23  last_updated       956 non-null    str
# dtypes: float64(3), int64(3), str(18)
# memory usage: 179.4 KB

# %% [markdown]
# * ¿Qué columnas tienen faltantes?
# * ¿La columna 'municipality' está completa?

# %% [markdown]
# ¿Cómo podemos obtener los valores de algunos cálculos estadísticos básicos, sobre las columnas con datos numéricos?

# %%
df_airports.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft  \
# count     956.000000    956.000000     956.000000    923.000000
# mean   118210.355649    -35.383056     -62.909503    798.489707
# std    142947.208708      6.700479       4.105636   1291.436631
# min        13.000000    -54.843300     -72.885820      6.000000
# 25%     38754.750000    -38.007926     -65.488549    131.500000
# 50%     38998.500000    -34.441482     -62.163550    314.000000
# 75%    318244.250000    -31.469025     -59.466248    900.500000
# max    596544.000000    -22.123510     -53.672578  13000.000000
#
#        scheduled_service        score
# count         956.000000   956.000000
# mean            0.053347    84.675732
# std             0.224843   156.354911
# min             0.000000     0.000000
# 25%             0.000000    50.000000
# 50%             0.000000    50.000000
# 75%             0.000000    50.000000
# max             1.000000  1275.000000

# %% [markdown]
# ¿Qué es cada cálculo?
# * **count**: cantidad de valores no nulos
# * **mean**: media, el valor promedio de un conjunto de datos
# * **std**: desviación estándar, cuánto varían los valores en relación con la media.
# * **min**: mínimo
# * **25%**(primer cuartil): indica el valor por debajo del cual cae el 25% de los datos.
# * **50%**(mediana): es el valor que divide la serie en dos mitades iguales.
# * **75%**(tercer cuartil): indica el valor por debajo del cual cae el 75% de los datos.
# * **max**: máximo

# %%
df_airports.dtypes
# Out:
# id                     int64
# ident                    str
# type                     str
# name                     str
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft         float64
# continent                str
# country_name             str
# iso_country              str
# region_name              str
# iso_region               str
# local_region             str
# municipality             str
# scheduled_service      int64
# gps_code                 str
# icao_code                str
# iata_code                str
# local_code               str
# home_link                str
# wikipedia_link           str
# keywords                 str
# score                  int64
# last_updated             str
# dtype: object

# %% [markdown]
# * **info()**: cantidad de valores nulos por columnas y tipo de datos que pandas le asignó.
# * **describe()**: cálculos sobre las columnas que contienen datos numéricos.
# * **dtypes**: solamente los tipos de datos asignados por pandas.
#     * [Info tipos de datos](https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#basics-dtypes)

# %% [markdown]
# * Otras operaciones estadísticas :
#     * min, max
#     * argmin, argmax
#     * idxmin, idxmax
#     * quantile
#     * sum
#     * mean
#     * median
#     * mad: desviación absoluta media respecto al valor medio
#     * prod: producto de todos los valores
#     * var: varianza muestral de los valores
#     * std: desviación estándar muestral de los valores
#     * skew: asimetría muestral
#     * kurt: curtosis muestral de los valores
#     * cumsum: suma acumulativa de los valores
#     * cummin, cummax: mínimo o máximo acumulativo de los valores
#     * cumprod: calcular la primera diferencia aritmética
#     * pct_change: calcular cambios porcentuales
# > Capítulo 5.3 "Python for Data Analysis"

# %% [markdown]
# ¿Cuánta memoria estamos usando con nuestro dataset?

# %%
file_ind = 'usu_individual_T324.txt'

# %%
usi_ind = pd.read_csv(file_route/file_ind, delimiter=';')
# Out:
# C:\Users\Fran\AppData\Local\Temp\ipykernel_20232\3655132522.py:1: DtypeWarning: Columns (0: PP09A_ESP) have mixed types. Specify dtype option on import or set low_memory=False.
#   usi_ind = pd.read_csv(file_route/file_ind, delimiter=';')

# %% [markdown]
# El error :
# > DtypeWarning: Columns (102) have mixed types. Specify dtype option on import or set low_memory=False
# >
# * **pandas** indica que la columna 102 del archivo contiene datos de diferentes tipos (por ejemplo, números y cadenas de texto).
#   Esto puede causar problemas al procesar los datos, ya que pandas no sabe cómo manejar esos tipos mixtos.
# * Se puede usar **low_memory=False**:  pandas procesa el archivo sin advertencias.

# %%
usi_ind = pd.read_csv(file_route/file_ind, delimiter=';', low_memory=False)

# %%
usi_ind.info(verbose=False, memory_usage='deep')
df_airports.info(verbose=False, memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47564 entries, 0 to 47563
# Columns: 177 entries, CODUSU to PONDIH
# dtypes: float64(105), int64(66), str(6)
# memory usage: 75.9 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Columns: 24 entries, id to last_updated
# dtypes: float64(3), int64(3), str(18)
# memory usage: 911.9 KB

# %% [markdown]
# #### 👉 Quiero saber la cantidad de aeropuertos que hay de cada tipo

# %% [markdown]
# #### 1. Consulto los nombres de las columnas para saber donde está esa información

# %%
df_airports.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'country_name', 'iso_country',
#        'region_name', 'iso_region', 'local_region', 'municipality',
#        'scheduled_service', 'gps_code', 'icao_code', 'iata_code', 'local_code',
#        'home_link', 'wikipedia_link', 'keywords', 'score', 'last_updated'],
#       dtype='str')

# %% [markdown]
# #### 2. Consulto cuáles son los valores únicos de la columna **type**

# %%
df_airports.type.unique()
# Out:
# <StringArray>
# [ 'large_airport', 'medium_airport',         'closed',  'small_airport',
#        'heliport',    'balloonport']
# Length: 6, dtype: str

# %% [markdown]
# #### 3. Calculo cuántos hay de cada tipo

# %%
df_airports['type'].value_counts()
# Out:
# type
# small_airport     694
# heliport          148
# medium_airport     69
# closed             42
# large_airport       2
# balloonport         1
# Name: count, dtype: int64

# %% [markdown]
# ## 📌 Trabajando con datos de una sola columna
#  * Queremos guardar los nombres de todos los aeropuertos

# %%
df_names = df_airports.name

# %%
df_names
# Out:
# 0               Minister Pistarini International Airport
# 1                                  Jorge Newbery Airpark
# 2      Ushuaia - Malvinas Argentinas International Ai...
# 3             Cataratas Del Iguazú International Airport
# 4      El Calafate - Commander Armando Tola Internati...
#                              ...
# 951                           Agrodistribuidora Airstrip
# 952    Dayry Partners Americas Manufacturing Argentin...
# 953                                  Villa Unión Airport
# 954                                        Roca Heliport
# 955                                Austral S.A. Heliport
# Name: name, Length: 956, dtype: str

# %% [markdown]
# ¿Cómo puedo obtener los nombres en una estructura más simple?

# %%
df_airports.name.to_list()[:5]
# Out:
# ['Minister Pistarini International Airport',
#  'Jorge Newbery Airpark',
#  'Ushuaia - Malvinas Argentinas International Airport',
#  'Cataratas Del Iguazú International Airport',
#  'El Calafate - Commander Armando Tola International Airport']

# %%
df_airports.name.values[:5]
# Out:
# <StringArray>
# [                  'Minister Pistarini International Airport',
#                                       'Jorge Newbery Airpark',
#         'Ushuaia - Malvinas Argentinas International Airport',
#                  'Cataratas Del Iguazú International Airport',
#  'El Calafate - Commander Armando Tola International Airport']
# Length: 5, dtype: str

# %% [markdown]
# ```
# df_airports.name.to_list()
#  ```
# * Convierte la columna en una lista de Python.
# * **Tipo de Objeto Devuelto**: devuelve una lista de Python (list).
# * **Uso**: es útil cuando se necesita trabajar con los datos como una lista, ya que las listas son una estructura de datos nativa de Python y son fáciles de manipular.

# %% [markdown]
# ```
# df_airports.name.values
#  ```
# * Devuelve los valores de la serie como un array de NumPy.
# * **Tipo de Objeto Devuelto**: devuelve un array de NumPy (numpy.ndarray).
# * **Uso**: es útil cuando se necesita realizar operaciones numéricas o de matriz, ya que NumPy proporciona una amplia gama de funciones y métodos optimizados para trabajar con arrays.
# * Veremos más adelante qué características tiene la librería NumPy y las facilidades que provee.

# %% [markdown]
# ¿Pero es lo mismo un Dataframe que una variable de tipo Series?

# %% [markdown]
# ### 📌 Series
# * Tipo de dato unidimensional, es como un arreglo con etiquetas de índice.
# * Los tipos de operaciones pueden variar con respecto a un Dataframe.
# * [Info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)

# %%
df_airports.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft  \
# count     956.000000    956.000000     956.000000    923.000000
# mean   118210.355649    -35.383056     -62.909503    798.489707
# std    142947.208708      6.700479       4.105636   1291.436631
# min        13.000000    -54.843300     -72.885820      6.000000
# 25%     38754.750000    -38.007926     -65.488549    131.500000
# 50%     38998.500000    -34.441482     -62.163550    314.000000
# 75%    318244.250000    -31.469025     -59.466248    900.500000
# max    596544.000000    -22.123510     -53.672578  13000.000000
#
#        scheduled_service        score
# count         956.000000   956.000000
# mean            0.053347    84.675732
# std             0.224843   156.354911
# min             0.000000     0.000000
# 25%             0.000000    50.000000
# 50%             0.000000    50.000000
# 75%             0.000000    50.000000
# max             1.000000  1275.000000

# %%
type(df_airports.elevation_ft)
# Out:
# pandas.Series

# %%
df_airports.elevation_ft.describe()
# Out:
# count      923.000000
# mean       798.489707
# std       1291.436631
# min          6.000000
# 25%        131.500000
# 50%        314.000000
# 75%        900.500000
# max      13000.000000
# Name: elevation_ft, dtype: float64

# %% [markdown]
# 1. Las estadísticas se muestran de todas las columnas númericas.
# 2. Las estadísticas se muestran sólo de la columna seleccionada.

# %% [markdown]
# La estructura **Series** tiene dos componentes principales: índice y valores:
# *  **Índice (index)** es una etiqueta que se utiliza para **identificar** cada uno de los elementos de la Serie.
#     *  Por defecto, si no se especifica un índice al crear la Serie, pandas asigna un índice numérico que comienza en 0 y se incrementa en 1 para cada elemento.
#     *  **index**: permite acceder a los valores.
# *  **Valores (values)**: son los datos que contiene.
#     *  **values**: permite acceder a los valores.

# %%
df_airports.elevation_ft.index
# Out:
# RangeIndex(start=0, stop=956, step=1)

# %%
df_airports.elevation_ft.values[:5]
# Out:
# array([ 67.,  18., 102., 916., 669.])

# %% [markdown]
# ### 📌 Acceso a datos por índice o etiquetas

# %%
df_airports.iloc[10:14]
# Out:
#       id ident            type                                          name  \
# 10  5834  SAWG  medium_airport             Piloto Civil N. Fernández Airport
# 11  5775  SADF  medium_airport                          San Fernando Airport
# 12  5827  SAVT  medium_airport            Almirante Marco Andres Zar Airport
# 13  5769  SAAR  medium_airport  Rosario Islas Malvinas International Airport
#
#     latitude_deg  longitude_deg  elevation_ft continent country_name  \
# 10      -51.6089       -69.3126          61.0        SA    Argentina
# 11      -34.4532       -58.5896          10.0        SA    Argentina
# 12      -43.2105       -65.2703         141.0        SA    Argentina
# 13      -32.9036       -60.7850          85.0        SA    Argentina
#
#    iso_country  ... scheduled_service gps_code icao_code iata_code  \
# 10          AR  ...                 1     SAWG      SAWG       RGL
# 11          AR  ...                 0     SADF       NaN       NaN
# 12          AR  ...                 1     SAVT      SAVT       REL
# 13          AR  ...                 1     SAAR      SAAR       ROS
#
#     local_code home_link                                     wikipedia_link  \
# 10         GAL       NaN  https://en.wikipedia.org/wiki/Piloto_Civil_Nor...
# 11         FDO       NaN  https://en.wikipedia.org/wiki/San_Fernando_Air...
# 12         TRE       NaN  https://en.wikipedia.org/wiki/Almirante_Marco_...
# 13         ROS       NaN  https://en.wikipedia.org/wiki/Rosario_Internat...
#
#                               keywords score               last_updated
# 10      Brigadier General D. A. Parodi   750  2011-02-13T13:44:01+00:00
# 11  San Fernando International Airport   250  2022-01-23T12:53:12+00:00
# 12                      Trelew Airport   750  2011-07-03T03:21:25+00:00
# 13                   Fisherton Airport   750  2021-10-29T23:02:12+00:00
#
# [4 rows x 24 columns]

# %%
df_airports.loc[10:14]
# Out:
#       id ident            type                                          name  \
# 10  5834  SAWG  medium_airport             Piloto Civil N. Fernández Airport
# 11  5775  SADF  medium_airport                          San Fernando Airport
# 12  5827  SAVT  medium_airport            Almirante Marco Andres Zar Airport
# 13  5769  SAAR  medium_airport  Rosario Islas Malvinas International Airport
# 14  5848  SAZN  medium_airport                      Presidente Peron Airport
#
#     latitude_deg  longitude_deg  elevation_ft continent country_name  \
# 10    -51.608900     -69.312600          61.0        SA    Argentina
# 11    -34.453200     -58.589600          10.0        SA    Argentina
# 12    -43.210500     -65.270300         141.0        SA    Argentina
# 13    -32.903600     -60.785000          85.0        SA    Argentina
# 14    -38.949001     -68.155701         895.0        SA    Argentina
#
#    iso_country  ... scheduled_service gps_code icao_code iata_code  \
# 10          AR  ...                 1     SAWG      SAWG       RGL
# 11          AR  ...                 0     SADF       NaN       NaN
# 12          AR  ...                 1     SAVT      SAVT       REL
# 13          AR  ...                 1     SAAR      SAAR       ROS
# 14          AR  ...                 1     SAZN      SAZN       NQN
#
#     local_code home_link                                     wikipedia_link  \
# 10         GAL       NaN  https://en.wikipedia.org/wiki/Piloto_Civil_Nor...
# 11         FDO       NaN  https://en.wikipedia.org/wiki/San_Fernando_Air...
# 12         TRE       NaN  https://en.wikipedia.org/wiki/Almirante_Marco_...
# 13         ROS       NaN  https://en.wikipedia.org/wiki/Rosario_Internat...
# 14         NEU       NaN  https://en.wikipedia.org/wiki/Presidente_Per%C...
#
#                               keywords score               last_updated
# 10      Brigadier General D. A. Parodi   750  2011-02-13T13:44:01+00:00
# 11  San Fernando International Airport   250  2022-01-23T12:53:12+00:00
# 12                      Trelew Airport   750  2011-07-03T03:21:25+00:00
# 13                   Fisherton Airport   750  2021-10-29T23:02:12+00:00
# 14                                 NaN   750  2018-09-14T02:31:14+00:00
#
# [5 rows x 24 columns]

# %% [markdown]
# * **loc**: por label, en este caso el índice en un número
# * **iloc**: por índice entero, es el número de la fila.
# * Más info de acceso indexado en:
# > Capítulo 5.2 "Python for Data Analysis"

# %% [markdown]
# ## 🎒 Manipulación de Datos con pandas
# * ¿Cómo seleccionar, filtrar y transformar datos?
# * ¿Cuáles son las operaciones comunes para manipular y procesar datos?

# %% [markdown]
# ### 📌 Filtrado de datos

# %% [markdown]
# * Filas que coincidan con  un valor específico de una columna.
# * Filas que cumplan condición con operadores booleanos.
# * Selección de columnas específicas.
# * Filas que coincidan con algún string o elemento de una lista.

# %% [markdown]
# 👉 Queremos encontrar:
# * los aeropuertos que coincidan con un tipo de aeropuerto dado.
# * los aeropuertos que se encuentren en valores o rangos correspondientes a la elevación.
# * los aeropuertos de tipo: large, medium, small.

# %% [markdown]
# #### 👉 Los aeropuertos que coincidan con un tipo de aeropuerto dado.

# %%
df_airports[df_airports.type=='medium_airport']
# Out:
#        id ident            type  \
# 2    5835  SAWH  medium_airport
# 3    5806  SARI  medium_airport
# 4    5831  SAWC  medium_airport
# 5    5786  SAME  medium_airport
# 6    5852  SAZS  medium_airport
# ..    ...   ...             ...
# 164  5813  SASO  medium_airport
# 165  5784  SAHS  medium_airport
# 166  5844  SAZH  medium_airport
# 167  5797  SAOD  medium_airport
# 168  5785  SAHZ  medium_airport
#
#                                                   name  latitude_deg  \
# 2    Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3           Cataratas Del Iguazú International Airport    -25.737301
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# 5                                El Plumerillo Airport    -32.831699
# 6                      San Carlos de Bariloche Airport    -41.151199
# ..                                                 ...           ...
# 164                                       Orán Airport    -23.152800
# 165                       Rincon De Los Sauces Airport    -37.390598
# 166                               Tres Arroyos Airport    -38.386900
# 167                              Villa Dolores Airport    -31.945200
# 168                                     Zapala Airport    -38.975498
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 2       -68.295800         102.0        SA    Argentina          AR  ...
# 3       -54.473400         916.0        SA    Argentina          AR  ...
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# 5       -68.792900        2310.0        SA    Argentina          AR  ...
# 6       -71.157501        2774.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 164     -64.329201        1171.0        SA    Argentina          AR  ...
# 165     -68.904198        1968.0        SA    Argentina          AR  ...
# 166     -60.329700         400.0        SA    Argentina          AR  ...
# 167     -65.146301        1847.0        SA    Argentina          AR  ...
# 168     -70.113602        3330.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 2                   1     SAWH      SAWH       USH         USU
# 3                   1     SARI      SARI       IGR         IGU
# 4                   1     SAWC       NaN       FTE         ECA
# 5                   1     SAME      SAME       MDZ         DOZ
# 6                   1     SAZS      SAZS       BRC         BAR
# ..                ...      ...       ...       ...         ...
# 164                 0     SASO      SASO       ORA         ORA
# 165                 0     SAHS      SAHS       RDS         RIN
# 166                 0     SAZH      SAZH       OYO         YOS
# 167                 0     SAOD      SAOD       VDR         LDR
# 168                 0     SAHZ      SAHZ       APZ         ZAP
#
#                                    home_link  \
# 2                                        NaN
# 3            http://www.aa2000.com.ar/iguazu
# 4    http://www.aeropuertoelcalafate.com/en/
# 5                                        NaN
# 6         http://www.aa2000.com.ar/bariloche
# ..                                       ...
# 164                                      NaN
# 165                                      NaN
# 166                                      NaN
# 167                                      NaN
# 168                                      NaN
#
#                                         wikipedia_link  \
# 2    https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...
# 3    https://en.wikipedia.org/wiki/Cataratas_del_Ig...
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...
# 5    https://en.wikipedia.org/wiki/Governor_Francis...
# 6    https://en.wikipedia.org/wiki/San_Carlos_de_Ba...
# ..                                                 ...
# 164    https://en.wikipedia.org/wiki/Or%C3%A1n_Airport
# 165  https://en.wikipedia.org/wiki/Rinc%C3%B3n_de_l...
# 166  https://en.wikipedia.org/wiki/Tres_Arroyos_Air...
# 167  https://en.wikipedia.org/wiki/Villa_Dolores_Ai...
# 168       https://en.wikipedia.org/wiki/Zapala_Airport
#
#                      keywords score               last_updated
# 2                         NaN   750  2025-03-22T20:48:42+00:00
# 3                      Iguaçu   750  2018-09-13T12:34:47+00:00
# 4                         NaN   500  2022-01-12T18:23:15+00:00
# 5                         NaN   750  2011-02-17T01:49:01+00:00
# 6    Teniente Luis Candelaria   750  2025-03-09T01:30:49+00:00
# ..                        ...   ...                        ...
# 164                       NaN   250  2024-05-16T20:11:54+00:00
# 165                       NaN   250  2024-05-16T20:10:19+00:00
# 166                       NaN   250  2022-01-23T17:31:31+00:00
# 167                       NaN   250  2024-05-19T23:13:37+00:00
# 168                       NaN   250  2016-06-01T05:54:24+00:00
#
# [69 rows x 24 columns]

# %% [markdown]
# ¿Por qué usamos dos veces la variable **df_airports**?

# %%
df_airports.type=='medium_airport'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# Name: type, Length: 956, dtype: bool

# %% [markdown]
# * Nos devuelve un array de booleanos, es en realidad una máscara.
# * Luego se aplica esa máscara a las filas del Dataframe.

# %%
df_airports.type.unique()
# Out:
# <StringArray>
# [ 'large_airport', 'medium_airport',         'closed',  'small_airport',
#        'heliport',    'balloonport']
# Length: 6, dtype: str

# %%
mask = df_airports.type=='medium_airport'
df_airports[mask].head(3)
# Out:
#      id ident            type  \
# 2  5835  SAWH  medium_airport
# 3  5806  SARI  medium_airport
# 4  5831  SAWC  medium_airport
#
#                                                 name  latitude_deg  \
# 2  Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3         Cataratas Del Iguazú International Airport    -25.737301
# 4  El Calafate - Commander Armando Tola Internati...    -50.280300
#
#    longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 2     -68.295800         102.0        SA    Argentina          AR  ...
# 3     -54.473400         916.0        SA    Argentina          AR  ...
# 4     -72.053101         669.0        SA    Argentina          AR  ...
#
#   scheduled_service gps_code icao_code iata_code  local_code  \
# 2                 1     SAWH      SAWH       USH         USU
# 3                 1     SARI      SARI       IGR         IGU
# 4                 1     SAWC       NaN       FTE         ECA
#
#                                  home_link  \
# 2                                      NaN
# 3          http://www.aa2000.com.ar/iguazu
# 4  http://www.aeropuertoelcalafate.com/en/
#
#                                       wikipedia_link keywords score  \
# 2  https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...      NaN   750
# 3  https://en.wikipedia.org/wiki/Cataratas_del_Ig...   Iguaçu   750
# 4  https://en.wikipedia.org/wiki/Comandante_Arman...      NaN   500
#
#                 last_updated
# 2  2025-03-22T20:48:42+00:00
# 3  2018-09-13T12:34:47+00:00
# 4  2022-01-12T18:23:15+00:00
#
# [3 rows x 24 columns]

# %% [markdown]
# #### 👉 Los aeropuertos que se encuentren en valores o rangos correspondientes a la elevación.

# %%
df_airports[df_airports.elevation_ft<131].head(3)
# Out:
#      id ident            type  \
# 0  5781  SAEZ   large_airport
# 1  5771  SABE   large_airport
# 2  5835  SAWH  medium_airport
#
#                                                 name  latitude_deg  \
# 0           Minister Pistarini International Airport      -34.8222
# 1                              Jorge Newbery Airpark      -34.5592
# 2  Ushuaia - Malvinas Argentinas International Ai...      -54.8433
#
#    longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -58.5358          67.0        SA    Argentina          AR  ...
# 1       -58.4156          18.0        SA    Argentina          AR  ...
# 2       -68.2958         102.0        SA    Argentina          AR  ...
#
#   scheduled_service gps_code icao_code iata_code  local_code  \
# 0                 1     SAEZ      SAEZ       EZE         EZE
# 1                 1     SABE      SABE       AEP         AER
# 2                 1     SAWH      SAWH       USH         USU
#
#                             home_link  \
# 0  http://www.aa2000.com.ar/index.php
# 1                                 NaN
# 2                                 NaN
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1  https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2  https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
#
#                 last_updated
# 0  2022-10-27T15:05:29+00:00
# 1  2021-10-07T15:55:36+00:00
# 2  2025-03-22T20:48:42+00:00
#
# [3 rows x 24 columns]

# %%
df_airports[(df_airports.elevation_ft>131) & (df_airports.elevation_ft<903)]
# Out:
#          id    ident            type  \
# 4      5831     SAWC  medium_airport
# 12     5827     SAVT  medium_airport
# 14     5848     SAZN  medium_airport
# 15     5822     SAVC  medium_airport
# 16     5836     SAWJ  medium_airport
# ..      ...      ...             ...
# 948   42895  AR-0473        heliport
# 951  333824  AR-0654          closed
# 952   42893  AR-0471        heliport
# 953  333815  AR-0652          closed
# 955   42905  AR-0483        heliport
#
#                                                   name  latitude_deg  \
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# 12                  Almirante Marco Andres Zar Airport    -43.210500
# 14                            Presidente Peron Airport    -38.949001
# 15                          General E. Mosconi Airport    -45.785300
# 16                    Capitan D Daniel Vazquez Airport    -49.306816
# ..                                                 ...           ...
# 948                      Estancia La Pascuala Heliport    -37.393600
# 951                         Agrodistribuidora Airstrip    -29.220089
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 953                                Villa Unión Airport    -29.422180
# 955                              Austral S.A. Heliport    -52.738600
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# 12      -65.270300         141.0        SA    Argentina          AR  ...
# 14      -68.155701         895.0        SA    Argentina          AR  ...
# 15      -67.465500         189.0        SA    Argentina          AR  ...
# 16      -67.802596         203.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 948     -58.966100         721.0        SA    Argentina          AR  ...
# 951     -61.760298         220.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 953     -62.789526         248.0        SA    Argentina          AR  ...
# 955     -68.572500         290.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 4                   1     SAWC       NaN       FTE         ECA
# 12                  1     SAVT      SAVT       REL         TRE
# 14                  1     SAZN      SAZN       NQN         NEU
# 15                  1     SAVC      SAVC       CRD         CRV
# 16                  0     SAWJ      SAWJ       ULA         SJU
# ..                ...      ...       ...       ...         ...
# 948                 0      NaN       NaN       NaN         HTD
# 951                 0      NaN       NaN       NaN         NaN
# 952                 0      NaN       NaN       NaN         HNE
# 953                 0      NaN       NaN       NaN         NaN
# 955                 0      NaN       NaN       NaN         HCP
#
#                                    home_link  \
# 4    http://www.aeropuertoelcalafate.com/en/
# 12                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# ..                                       ...
# 948                                      NaN
# 951                                      NaN
# 952                                      NaN
# 953                                      NaN
# 955                                      NaN
#
#                                         wikipedia_link        keywords score  \
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...             NaN   500
# 12   https://en.wikipedia.org/wiki/Almirante_Marco_...  Trelew Airport   750
# 14   https://en.wikipedia.org/wiki/Presidente_Per%C...             NaN   750
# 15   https://en.wikipedia.org/wiki/General_Enrique_...             NaN   750
# 16   https://en.wikipedia.org/wiki/Capit%C3%A1n_Jos...             NaN   750
# ..                                                 ...             ...   ...
# 948                                                NaN             NaN     0
# 951                                                NaN             NaN     0
# 952                                                NaN             NaN     0
# 953                                                NaN             NaN     0
# 955                                                NaN             NaN     0
#
#                   last_updated
# 4    2022-01-12T18:23:15+00:00
# 12   2011-07-03T03:21:25+00:00
# 14   2018-09-14T02:31:14+00:00
# 15   2024-04-29T19:43:44+00:00
# 16   2025-02-05T15:21:04+00:00
# ..                         ...
# 948  2009-10-20T11:13:21+00:00
# 951  2020-04-12T12:30:36+00:00
# 952  2009-10-20T11:13:21+00:00
# 953  2020-04-10T04:01:54+00:00
# 955  2021-10-07T11:46:03+00:00
#
# [461 rows x 24 columns]

# %% [markdown]
# ¿Son los mismos operadores booleanos usados en Python?

# %% [markdown]
# ### 📌 Operadores booleanos
# |Operador|Python|pandas|
# |----------|---------|--------|
# |**and**|cond1 and cond2|(cond1) & (cond2)|
# |**or**|cond1 or cond2|(cond1) \| (cond2)|
# |**not**|not cond|∼cond|

# %% [markdown]
# Cuando filtramos por valores numéricos podemos utilizar **between** en lugar de poner explícitamente ambas condiciones

# %%
df_airports[df_airports.elevation_ft.between(131, 903)]
# Out:
#          id    ident            type  \
# 4      5831     SAWC  medium_airport
# 12     5827     SAVT  medium_airport
# 14     5848     SAZN  medium_airport
# 15     5822     SAVC  medium_airport
# 16     5836     SAWJ  medium_airport
# ..      ...      ...             ...
# 948   42895  AR-0473        heliport
# 951  333824  AR-0654          closed
# 952   42893  AR-0471        heliport
# 953  333815  AR-0652          closed
# 955   42905  AR-0483        heliport
#
#                                                   name  latitude_deg  \
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# 12                  Almirante Marco Andres Zar Airport    -43.210500
# 14                            Presidente Peron Airport    -38.949001
# 15                          General E. Mosconi Airport    -45.785300
# 16                    Capitan D Daniel Vazquez Airport    -49.306816
# ..                                                 ...           ...
# 948                      Estancia La Pascuala Heliport    -37.393600
# 951                         Agrodistribuidora Airstrip    -29.220089
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 953                                Villa Unión Airport    -29.422180
# 955                              Austral S.A. Heliport    -52.738600
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# 12      -65.270300         141.0        SA    Argentina          AR  ...
# 14      -68.155701         895.0        SA    Argentina          AR  ...
# 15      -67.465500         189.0        SA    Argentina          AR  ...
# 16      -67.802596         203.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 948     -58.966100         721.0        SA    Argentina          AR  ...
# 951     -61.760298         220.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 953     -62.789526         248.0        SA    Argentina          AR  ...
# 955     -68.572500         290.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 4                   1     SAWC       NaN       FTE         ECA
# 12                  1     SAVT      SAVT       REL         TRE
# 14                  1     SAZN      SAZN       NQN         NEU
# 15                  1     SAVC      SAVC       CRD         CRV
# 16                  0     SAWJ      SAWJ       ULA         SJU
# ..                ...      ...       ...       ...         ...
# 948                 0      NaN       NaN       NaN         HTD
# 951                 0      NaN       NaN       NaN         NaN
# 952                 0      NaN       NaN       NaN         HNE
# 953                 0      NaN       NaN       NaN         NaN
# 955                 0      NaN       NaN       NaN         HCP
#
#                                    home_link  \
# 4    http://www.aeropuertoelcalafate.com/en/
# 12                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# ..                                       ...
# 948                                      NaN
# 951                                      NaN
# 952                                      NaN
# 953                                      NaN
# 955                                      NaN
#
#                                         wikipedia_link        keywords score  \
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...             NaN   500
# 12   https://en.wikipedia.org/wiki/Almirante_Marco_...  Trelew Airport   750
# 14   https://en.wikipedia.org/wiki/Presidente_Per%C...             NaN   750
# 15   https://en.wikipedia.org/wiki/General_Enrique_...             NaN   750
# 16   https://en.wikipedia.org/wiki/Capit%C3%A1n_Jos...             NaN   750
# ..                                                 ...             ...   ...
# 948                                                NaN             NaN     0
# 951                                                NaN             NaN     0
# 952                                                NaN             NaN     0
# 953                                                NaN             NaN     0
# 955                                                NaN             NaN     0
#
#                   last_updated
# 4    2022-01-12T18:23:15+00:00
# 12   2011-07-03T03:21:25+00:00
# 14   2018-09-14T02:31:14+00:00
# 15   2024-04-29T19:43:44+00:00
# 16   2025-02-05T15:21:04+00:00
# ..                         ...
# 948  2009-10-20T11:13:21+00:00
# 951  2020-04-12T12:30:36+00:00
# 952  2009-10-20T11:13:21+00:00
# 953  2020-04-10T04:01:54+00:00
# 955  2021-10-07T11:46:03+00:00
#
# [467 rows x 24 columns]

# %% [markdown]
# #### 👉 Filtrado de los aeropuertos de tipo: large, medium, small

# %%
df_airports.type.unique()
# Out:
# <StringArray>
# [ 'large_airport', 'medium_airport',         'closed',  'small_airport',
#        'heliport',    'balloonport']
# Length: 6, dtype: str

# %% [markdown]
# Hay dos posibles formas
# * Filtrar los aeropuertos que contengan el string **airport**, ya que los demás no contienen ese string.
# * Filtrar con una lista que contenga las categorías que estamos buscando.

# %% [markdown]
# ### 👉1.Filtrar indicando el string **airport**, ya que los demás no lo contienen.

# %%
df_airports[df_airports.type.str.contains('airport')].head(2)
# Out:
#      id ident           type                                      name  \
# 0  5781  SAEZ  large_airport  Minister Pistarini International Airport
# 1  5771  SABE  large_airport                     Jorge Newbery Airpark
#
#    latitude_deg  longitude_deg  elevation_ft continent country_name  \
# 0      -34.8222       -58.5358          67.0        SA    Argentina
# 1      -34.5592       -58.4156          18.0        SA    Argentina
#
#   iso_country  ... scheduled_service gps_code icao_code iata_code  local_code  \
# 0          AR  ...                 1     SAEZ      SAEZ       EZE         EZE
# 1          AR  ...                 1     SABE      SABE       AEP         AER
#
#                             home_link  \
# 0  http://www.aa2000.com.ar/index.php
# 1                                 NaN
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1  https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
#
#                 last_updated
# 0  2022-10-27T15:05:29+00:00
# 1  2021-10-07T15:55:36+00:00
#
# [2 rows x 24 columns]

# %% [markdown]
# ```python
# df.column.str.contains('string')
# ```
# Permite filtrar las filas que en la  **columna** se encuentre el string dado

# %% [markdown]
# ### 👉2. Filtrar con una lista que contenga las categorías que estamos buscando.

# %%
airports_int = ['large_airport', 'medium_airport',  'small_airport']

# %%
df_airports_int = df_airports[df_airports.type.isin(airports_int)]
df_airports_int
# Out:
#          id    ident            type  \
# 0      5781     SAEZ   large_airport
# 1      5771     SABE   large_airport
# 2      5835     SAWH  medium_airport
# 3      5806     SARI  medium_airport
# 4      5831     SAWC  medium_airport
# ..      ...      ...             ...
# 793   42824  AR-0402   small_airport
# 794   42825  AR-0403   small_airport
# 795  324368  AR-0618   small_airport
# 796  348476  AR-0710   small_airport
# 797   42888  AR-0466   small_airport
#
#                                                   name  latitude_deg  \
# 0             Minister Pistarini International Airport    -34.822200
# 1                                Jorge Newbery Airpark    -34.559200
# 2    Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3           Cataratas Del Iguazú International Airport    -25.737301
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# ..                                                 ...           ...
# 793                                  El Jagüel Airport    -31.799400
# 794                               El Malagueño Airport    -31.699400
# 795                                     Timbo Airstrip    -31.826600
# 796                        Estancia El Reducto Airport    -39.796400
# 797                                     Yapeyú Airport    -29.443930
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -58.535800          67.0        SA    Argentina          AR  ...
# 1       -58.415600          18.0        SA    Argentina          AR  ...
# 2       -68.295800         102.0        SA    Argentina          AR  ...
# 3       -54.473400         916.0        SA    Argentina          AR  ...
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 793     -59.033900         200.0        SA    Argentina          AR  ...
# 794     -59.400600         180.0        SA    Argentina          AR  ...
# 795     -59.033300         187.0        SA    Argentina          AR  ...
# 796     -62.316130          16.0        SA    Argentina          AR  ...
# 797     -56.823915         214.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 0                   1     SAEZ      SAEZ       EZE         EZE
# 1                   1     SABE      SABE       AEP         AER
# 2                   1     SAWH      SAWH       USH         USU
# 3                   1     SARI      SARI       IGR         IGU
# 4                   1     SAWC       NaN       FTE         ECA
# ..                ...      ...       ...       ...         ...
# 793                 0      NaN       NaN       NaN         UEL
# 794                 0      NaN       NaN       NaN         VLL
# 795                 0      NaN       NaN       NaN         NaN
# 796                 0      NaN       NaN       NaN         NaN
# 797                 0      NaN       NaN       NaN         YPY
#
#                                    home_link  \
# 0         http://www.aa2000.com.ar/index.php
# 1                                        NaN
# 2                                        NaN
# 3            http://www.aa2000.com.ar/iguazu
# 4    http://www.aeropuertoelcalafate.com/en/
# ..                                       ...
# 793                                      NaN
# 794                                      NaN
# 795                                      NaN
# 796                                      NaN
# 797                                      NaN
#
#                                         wikipedia_link     keywords score  \
# 0    https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1    https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2    https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
# 3    https://en.wikipedia.org/wiki/Cataratas_del_Ig...       Iguaçu   750
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...          NaN   500
# ..                                                 ...          ...   ...
# 793                                                NaN          NaN    50
# 794                                                NaN          NaN    50
# 795                                                NaN          NaN    50
# 796                                                NaN          NaN    50
# 797                                                NaN          NaN    50
#
#                   last_updated
# 0    2022-10-27T15:05:29+00:00
# 1    2021-10-07T15:55:36+00:00
# 2    2025-03-22T20:48:42+00:00
# 3    2018-09-13T12:34:47+00:00
# 4    2022-01-12T18:23:15+00:00
# ..                         ...
# 793  2009-10-20T11:12:40+00:00
# 794  2009-10-20T11:12:40+00:00
# 795  2017-07-09T13:17:54+00:00
# 796  2021-10-07T15:19:46+00:00
# 797  2018-05-04T21:35:39+00:00
#
# [765 rows x 24 columns]

# %% [markdown]
# ```python
# df.columna.isin(lista)
# ```
# Permite filtrar las filas cuyo contenido de la **columna** dada sea algunos de los elementos de la **lista** pasada como parámetro.

# %% [markdown]
# # 📊 Gráficos con Matplotlib

# %% [markdown]
# ¿Qué tipos de gráficos conocen?

# %% [markdown]
# Con Matplotlib se pueden realizar
# * Barra
# * Línea
# * Torta
# * Scatter
# * Histograma
# * Boxplot
# * 3D
# * [y muchos más](https://matplotlib.org/stable/plot_types/index.html)

# %% [markdown]
# Primero importamos:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generar gráficos simples
# Graficar los tipos de aeropuertos según el tipo
# * barra
# * torta

# %% [markdown]
# #### Utilizando plot directamente con los valores contados

# %%
conteo_tipos = df_airports_int.type.value_counts()
conteo_tipos
# Out:
# type
# small_airport     694
# medium_airport     69
# large_airport       2
# Name: count, dtype: int64

# %%
type(conteo_tipos)
# Out:
# pandas.Series

# %% [markdown]
# ### Crear el gráfico de barra

# %%
conteo_tipos.plot(kind='bar', xlabel='Tipo de aeropuerto', ylabel='Cantidad', title='Cantidad de aeropuertos por tipo')
plt.show()

# %% [markdown]
# ### Crear el gráfico de torta

# %%
conteo_tipos.plot(kind='pie', autopct='%1.1f%%', title='Proporción de aeropuertos por tipo')

# Mostrar el gráfico de torta
plt.show()

# %% [markdown]
# ## 📊 Utilizando las funciones de Matplotlib

# %%
values = df_airports_int.type.value_counts().values
labels = df_airports_int.type.value_counts().index

# %% [markdown]
# ## 📌 Crear el gráfico de barras

# %%
plt.bar(labels,values)
# Agregar etiquetas y título
plt.xlabel('Tipo de aeropuerto')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por tipo')

# Rotar etiquetas en el eje x para mejor legibilidad
plt.xticks(rotation=45)
# Mostrar el gráfico de barras
plt.show()

# %% [markdown]
# ## 📌Crear el gráfico de torta

# %%
plt.pie(values, labels=labels, autopct='%1.2f%%')

# Agregar título
plt.title('Proporción de aeropuertos por tipo')

# Mostrar el gráfico de torta
plt.show()

# %% [markdown]
# * autopct: permite mostrar el porcentaje al lado de cada porción

# %% [markdown]
# ### 📝Cambio de los colores del gráficos

# %%
plt.pie(values, labels=labels, colors=['red'])
plt.title('Proporción de aeropuertos por tipo')

plt.show()

# %% [markdown]
# ### 📝Agregar sombras

# %%
plt.pie(values, labels=labels, shadow=True)
plt.title('Proporción de aeropuertos por tipo')

plt.show()

# %% [markdown]
# ### 📝 Separar una porción para remarcar

# %%
explode = (0.1, 0, 0)  # Separar la segunda porción (índice 1)
plt.pie(values, labels=labels, explode=explode)
plt.title('Proporción de aeropuertos por tipo')

plt.show()

# %%
explode = (0.1, 0, 0)  # Separar la segunda porción (índice 1)
plt.pie(values, labels=labels, explode=explode)
plt.title('Proporción de aeropuertos por tipo')
plt.legend(labels, loc='center left', bbox_to_anchor=(1.5, 0.5))
plt.show()

# %% [markdown]
# # Para pensar en casa
# * ¿Cómo manejar valores faltantes y duplicados en un conjunto de datos?
# * ¿Cómo agregamos columnas, y cómo podemos hacerlo aplicando una función?
# * ¿Qué técnicas ofrece pandas para realizar agregaciones y agrupaciones de datos?
# * Nuestros datos y gráficos interactuando con Streamlit.

# %% [markdown]
# # Seguimos la próxima ...

# %% [markdown]
# Ejemplos extras

# %% [markdown]
# #### Modificamos los nombres de las columnas

# %%
df_reducido =  df_airports[['type','name']]
df_reducido
# Out:
#                type                                               name
# 0     large_airport           Minister Pistarini International Airport
# 1     large_airport                              Jorge Newbery Airpark
# 2    medium_airport  Ushuaia - Malvinas Argentinas International Ai...
# 3    medium_airport         Cataratas Del Iguazú International Airport
# 4    medium_airport  El Calafate - Commander Armando Tola Internati...
# ..              ...                                                ...
# 951          closed                         Agrodistribuidora Airstrip
# 952        heliport  Dayry Partners Americas Manufacturing Argentin...
# 953          closed                                Villa Unión Airport
# 954        heliport                                      Roca Heliport
# 955        heliport                              Austral S.A. Heliport
#
# [956 rows x 2 columns]

# %%
df_reducido
# Out:
#                type                                               name
# 0     large_airport           Minister Pistarini International Airport
# 1     large_airport                              Jorge Newbery Airpark
# 2    medium_airport  Ushuaia - Malvinas Argentinas International Ai...
# 3    medium_airport         Cataratas Del Iguazú International Airport
# 4    medium_airport  El Calafate - Commander Armando Tola Internati...
# ..              ...                                                ...
# 951          closed                         Agrodistribuidora Airstrip
# 952        heliport  Dayry Partners Americas Manufacturing Argentin...
# 953          closed                                Villa Unión Airport
# 954        heliport                                      Roca Heliport
# 955        heliport                              Austral S.A. Heliport
#
# [956 rows x 2 columns]

# %%
df_reducido.rename(columns={'name': 'Nombre'})
# Out:
#                type                                             Nombre
# 0     large_airport           Minister Pistarini International Airport
# 1     large_airport                              Jorge Newbery Airpark
# 2    medium_airport  Ushuaia - Malvinas Argentinas International Ai...
# 3    medium_airport         Cataratas Del Iguazú International Airport
# 4    medium_airport  El Calafate - Commander Armando Tola Internati...
# ..              ...                                                ...
# 951          closed                         Agrodistribuidora Airstrip
# 952        heliport  Dayry Partners Americas Manufacturing Argentin...
# 953          closed                                Villa Unión Airport
# 954        heliport                                      Roca Heliport
# 955        heliport                              Austral S.A. Heliport
#
# [956 rows x 2 columns]

# %%
changes_columns = {'type':'tipo', 'name':'nombre'}

df_reducido.rename(columns=changes_columns)
# Out:
#                tipo                                             nombre
# 0     large_airport           Minister Pistarini International Airport
# 1     large_airport                              Jorge Newbery Airpark
# 2    medium_airport  Ushuaia - Malvinas Argentinas International Ai...
# 3    medium_airport         Cataratas Del Iguazú International Airport
# 4    medium_airport  El Calafate - Commander Armando Tola Internati...
# ..              ...                                                ...
# 951          closed                         Agrodistribuidora Airstrip
# 952        heliport  Dayry Partners Americas Manufacturing Argentin...
# 953          closed                                Villa Unión Airport
# 954        heliport                                      Roca Heliport
# 955        heliport                              Austral S.A. Heliport
#
# [956 rows x 2 columns]

# %% [markdown]
# #### Reemplazos en las celdas

# %%
df_airports.region_name.unique()
# Out:
# <StringArray>
# [         'Buenos Aires Province', 'Buenos Aires (Autonomous City)',
#       'Tierra del Fuego Province',              'Misiones Province',
#             'Santa Cruz Province',               'Mendoza Province',
#              'Río Negro Province',                 'Salta Province',
#                'Córdoba Province',                'Chubut Province',
#               'Santa Fe Province',               'Neuquén Province',
#               'La Pampa Province',             'Catamarca Province',
#             'Entre Ríos Province',                 'Chaco Province',
#               'San Juan Province',               'Tucumán Province',
#                  'Jujuy Province',               'Formosa Province',
#               'La Rioja Province',   'Santiago del Estero Province',
#               'San Luis Province',            'Corrientes Province']
# Length: 24, dtype: str

# %%
df_airports[df_airports.region_name.str.contains('Tierra del Fuego')]['region_name']
# Out:
# 2      Tierra del Fuego Province
# 19     Tierra del Fuego Province
# 45     Tierra del Fuego Province
# 111    Tierra del Fuego Province
# 145    Tierra del Fuego Province
# 146    Tierra del Fuego Province
# 176    Tierra del Fuego Province
# 330    Tierra del Fuego Province
# 371    Tierra del Fuego Province
# 372    Tierra del Fuego Province
# 379    Tierra del Fuego Province
# 653    Tierra del Fuego Province
# 742    Tierra del Fuego Province
# 802    Tierra del Fuego Province
# 869    Tierra del Fuego Province
# 870    Tierra del Fuego Province
# 883    Tierra del Fuego Province
# 884    Tierra del Fuego Province
# 885    Tierra del Fuego Province
# 904    Tierra del Fuego Province
# 905    Tierra del Fuego Province
# 935    Tierra del Fuego Province
# 944    Tierra del Fuego Province
# 955    Tierra del Fuego Province
# Name: region_name, dtype: str

# %%
df_airports.region_name.replace('Tierra del Fuego Province', 'Tierra del Fuego, Ántartida....', inplace=True)
# Out:
# C:\Users\Fran\AppData\Local\Temp\ipykernel_20232\2848806099.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_airports.region_name.replace('Tierra del Fuego Province', 'Tierra del Fuego, Ántartida....', inplace=True)
# 0                Buenos Aires Province
# 1       Buenos Aires (Autonomous City)
# 2      Tierra del Fuego, Ántartida....
# 3                    Misiones Province
# 4                  Santa Cruz Province
#                     ...
# 951                  Santa Fe Province
# 952                   Córdoba Province
# 953       Santiago del Estero Province
# 954                   Córdoba Province
# 955    Tierra del Fuego, Ántartida....
# Name: region_name, Length: 956, dtype: str

# %%
df_airports
# Out:
#          id    ident            type  \
# 0      5781     SAEZ   large_airport
# 1      5771     SABE   large_airport
# 2      5835     SAWH  medium_airport
# 3      5806     SARI  medium_airport
# 4      5831     SAWC  medium_airport
# ..      ...      ...             ...
# 951  333824  AR-0654          closed
# 952   42893  AR-0471        heliport
# 953  333815  AR-0652          closed
# 954   42903  AR-0481        heliport
# 955   42905  AR-0483        heliport
#
#                                                   name  latitude_deg  \
# 0             Minister Pistarini International Airport    -34.822200
# 1                                Jorge Newbery Airpark    -34.559200
# 2    Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3           Cataratas Del Iguazú International Airport    -25.737301
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# ..                                                 ...           ...
# 951                         Agrodistribuidora Airstrip    -29.220089
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 953                                Villa Unión Airport    -29.422180
# 954                                      Roca Heliport    -32.060000
# 955                              Austral S.A. Heliport    -52.738600
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -58.535800          67.0        SA    Argentina          AR  ...
# 1       -58.415600          18.0        SA    Argentina          AR  ...
# 2       -68.295800         102.0        SA    Argentina          AR  ...
# 3       -54.473400         916.0        SA    Argentina          AR  ...
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 951     -61.760298         220.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 953     -62.789526         248.0        SA    Argentina          AR  ...
# 954     -64.779400        3444.0        SA    Argentina          AR  ...
# 955     -68.572500         290.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 0                   1     SAEZ      SAEZ       EZE         EZE
# 1                   1     SABE      SABE       AEP         AER
# 2                   1     SAWH      SAWH       USH         USU
# 3                   1     SARI      SARI       IGR         IGU
# 4                   1     SAWC       NaN       FTE         ECA
# ..                ...      ...       ...       ...         ...
# 951                 0      NaN       NaN       NaN         NaN
# 952                 0      NaN       NaN       NaN         HNE
# 953                 0      NaN       NaN       NaN         NaN
# 954                 0      NaN       NaN       NaN         HYC
# 955                 0      NaN       NaN       NaN         HCP
#
#                                    home_link  \
# 0         http://www.aa2000.com.ar/index.php
# 1                                        NaN
# 2                                        NaN
# 3            http://www.aa2000.com.ar/iguazu
# 4    http://www.aeropuertoelcalafate.com/en/
# ..                                       ...
# 951                                      NaN
# 952                                      NaN
# 953                                      NaN
# 954                                      NaN
# 955                                      NaN
#
#                                         wikipedia_link     keywords score  \
# 0    https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1    https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2    https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
# 3    https://en.wikipedia.org/wiki/Cataratas_del_Ig...       Iguaçu   750
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...          NaN   500
# ..                                                 ...          ...   ...
# 951                                                NaN          NaN     0
# 952                                                NaN          NaN     0
# 953                                                NaN          NaN     0
# 954                                                NaN          NaN     0
# 955                                                NaN          NaN     0
#
#                   last_updated
# 0    2022-10-27T15:05:29+00:00
# 1    2021-10-07T15:55:36+00:00
# 2    2025-03-22T20:48:42+00:00
# 3    2018-09-13T12:34:47+00:00
# 4    2022-01-12T18:23:15+00:00
# ..                         ...
# 951  2020-04-12T12:30:36+00:00
# 952  2009-10-20T11:13:21+00:00
# 953  2020-04-10T04:01:54+00:00
# 954  2009-10-20T11:13:21+00:00
# 955  2021-10-07T11:46:03+00:00
#
# [956 rows x 24 columns]

# %%
plt.bar(labels,values)
# Agregar etiquetas y título
plt.xlabel('Tipo de aeropuerto')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por tipo')

# Rotar etiquetas en el eje x para mejor legibilidad
plt.xticks(rotation=45)
# Mostrar el gráfico de barras
plt.show()

# %% [markdown]
# #### Uso de colores en el gráficos

# %%
#plt.bar(labels, values, color='blue')  # Color azul
plt.bar(labels, values, color='#FF5733')  # Color naranja (código hexadecimal)
plt.xlabel('Tipo de aeropuerto')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por tipo')

# Rotar etiquetas en el eje x para mejor legibilidad
plt.xticks(rotation=45)
# Mostrar el gráfico de barras
plt.show()

# %% [markdown]
# #### Tamaño de la figura

# %%
plt.figure(figsize=(10, 6))
plt.bar(labels, values, color='#FF5733')  # Color naranja (código hexadecimal)
plt.xlabel('Tipo de aeropuerto')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por tipo')

# Rotar etiquetas en el eje x para mejor legibilidad
plt.xticks(rotation=45)
# Mostrar el gráfico de barras
plt.show()

# %%
df_airports
# Out:
#          id    ident            type  \
# 0      5781     SAEZ   large_airport
# 1      5771     SABE   large_airport
# 2      5835     SAWH  medium_airport
# 3      5806     SARI  medium_airport
# 4      5831     SAWC  medium_airport
# ..      ...      ...             ...
# 951  333824  AR-0654          closed
# 952   42893  AR-0471        heliport
# 953  333815  AR-0652          closed
# 954   42903  AR-0481        heliport
# 955   42905  AR-0483        heliport
#
#                                                   name  latitude_deg  \
# 0             Minister Pistarini International Airport    -34.822200
# 1                                Jorge Newbery Airpark    -34.559200
# 2    Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3           Cataratas Del Iguazú International Airport    -25.737301
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# ..                                                 ...           ...
# 951                         Agrodistribuidora Airstrip    -29.220089
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 953                                Villa Unión Airport    -29.422180
# 954                                      Roca Heliport    -32.060000
# 955                              Austral S.A. Heliport    -52.738600
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0       -58.535800          67.0        SA    Argentina          AR  ...
# 1       -58.415600          18.0        SA    Argentina          AR  ...
# 2       -68.295800         102.0        SA    Argentina          AR  ...
# 3       -54.473400         916.0        SA    Argentina          AR  ...
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 951     -61.760298         220.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 953     -62.789526         248.0        SA    Argentina          AR  ...
# 954     -64.779400        3444.0        SA    Argentina          AR  ...
# 955     -68.572500         290.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 0                   1     SAEZ      SAEZ       EZE         EZE
# 1                   1     SABE      SABE       AEP         AER
# 2                   1     SAWH      SAWH       USH         USU
# 3                   1     SARI      SARI       IGR         IGU
# 4                   1     SAWC       NaN       FTE         ECA
# ..                ...      ...       ...       ...         ...
# 951                 0      NaN       NaN       NaN         NaN
# 952                 0      NaN       NaN       NaN         HNE
# 953                 0      NaN       NaN       NaN         NaN
# 954                 0      NaN       NaN       NaN         HYC
# 955                 0      NaN       NaN       NaN         HCP
#
#                                    home_link  \
# 0         http://www.aa2000.com.ar/index.php
# 1                                        NaN
# 2                                        NaN
# 3            http://www.aa2000.com.ar/iguazu
# 4    http://www.aeropuertoelcalafate.com/en/
# ..                                       ...
# 951                                      NaN
# 952                                      NaN
# 953                                      NaN
# 954                                      NaN
# 955                                      NaN
#
#                                         wikipedia_link     keywords score  \
# 0    https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# 1    https://en.wikipedia.org/wiki/Aeroparque_Jorge...          NaN  1050
# 2    https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...          NaN   750
# 3    https://en.wikipedia.org/wiki/Cataratas_del_Ig...       Iguaçu   750
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...          NaN   500
# ..                                                 ...          ...   ...
# 951                                                NaN          NaN     0
# 952                                                NaN          NaN     0
# 953                                                NaN          NaN     0
# 954                                                NaN          NaN     0
# 955                                                NaN          NaN     0
#
#                   last_updated
# 0    2022-10-27T15:05:29+00:00
# 1    2021-10-07T15:55:36+00:00
# 2    2025-03-22T20:48:42+00:00
# 3    2018-09-13T12:34:47+00:00
# 4    2022-01-12T18:23:15+00:00
# ..                         ...
# 951  2020-04-12T12:30:36+00:00
# 952  2009-10-20T11:13:21+00:00
# 953  2020-04-10T04:01:54+00:00
# 954  2009-10-20T11:13:21+00:00
# 955  2021-10-07T11:46:03+00:00
#
# [956 rows x 24 columns]

# %%
df_airports.elevation_ft.min()
# Out:
# np.float64(6.0)

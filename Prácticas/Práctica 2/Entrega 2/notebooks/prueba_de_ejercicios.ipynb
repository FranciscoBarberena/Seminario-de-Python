# %%
import sys
sys.path.append('../src')
from Ejercicio1 import execute1
from Ejercicio2 import execute2
from Ejercicio3 import execute3
from Ejercicio4 import execute4
from Ejercicio5 import execute5
from Ejercicio6 import execute6
from Ejercicio7 import execute7
from Ejercicio8 import execute8
from Ejercicio9 import execute9

# %%
execute1()

# %%
execute2()

# %%
execute3()

# %%
execute4()

# %%
execute5()

# %%
execute6()

# %%
execute7()

# %%
execute8()

# %%
execute9()
